# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df= pd.read_csv("files/world_data_full_apply_nulos.csv", index_col = 0)

# %%
df.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# ...

# %% [markdown]
# 1. ¿Cómo se distribuye la tasa de natalidad en el conjunto de datos? ¿Hay algún patrón evidente?
#
# 2. ¿Existe una relación aparente entre la tasa de mortalidad infantil y la esperanza de vida? Proporciona una breve descripción de los patrones que observes.
#
# 3. ¿Cuál es el continente con la mayor cantidad de países en el conjunto de datos? Proporciona el porcentaje de países en ese continente.
#
# 4. ¿Cuál es la mediana de la esperanza de vida en Europa? Proporciona un rango intercuartil aproximado y verifica si existen valores atípicos. s
#
# 5. ¿Existen relaciones visibles entre la tasa de natalidad y las siguientes variables: tasa de mortalidad infantil, esperanza de vida, densidad de población y población urbana? Usa un subplot. Describe cualquier patrón que encuentres.
#
# 6. ¿Cuáles son los 10 países con la mayor área forestal?
#
# 7. ¿Existen diferencias notables en la distribución de la tasa de natalidad entre continentes?
#
# 8. ¿Cómo se relacionan el CPI y el precio de la gasolina? Crea un scatter plot que muestre esta relación y agrega una línea para visualizar la tendencia. Ajusta los valores del CPI entre 100 y 300.
#
# 9. ¿Cómo varía la esperanza de vida entre los diferentes países de Oceanía? Utiliza un diagrama de violín para representar la distribución de la esperanza de vida en función del idioma oficial de cada país.
#
# 10. Queremos analizar la relación entre la tasa de impuestos total, el PIB per cápita y la tasa de alfabetización. Crea un conjunto de subplots con tres gráficas:
#
# - Un scatter plot que muestre la relación entre el PIB per cápita y el CPI.
#
# - Un histograma de la tasa de impuestos total.
#
# - Un gráfico de barras que resuma la tasa de impuestos total por continente.

# %% [markdown]
# Requisitos que deben cumplir las gráficas:
#
# - Todas deben llevar título.
#
# - Los nombres de los ejes deben estar en castellano.
#
# - En los scatterplot los puntos deben tener un tamaño de 2.
#
# - En los scatterplot los puntos deben tener un color diferente al azul.
#
# - En los barplot las barras siempre tienen que estar ordenadas de mayor a menor.
#
# - En los barplot y countplot las barras tienen que tener un color diferente a los que vienen por defecto.
#
# - En los pieplot los quesitos deben tener unos colores diferentes a los que vienen por defecto.
#
# - En los pieplot siempre tenemos que añadir la etiqueta de a que % corresponde cada quesito.
#
# - En los pieplot el tamaño de los % tiene que ser de 6.

# %%
df.columns
# Out:
# Index(['country', 'density', 'abbreviation', 'agricultural_land', 'land_area',
#        'armed_forces_size', 'birth_rate', 'calling_code', 'capital/major_city',
#        'co2-emissions', 'cpi', 'cpi_change', 'currency-code', 'fertility_rate',
#        'forested_area', 'gasoline_price', 'gdp',
#        'gross_primary_education_enrollment',
#        'gross_tertiary_education_enrollment', 'infant_mortality',
#        'largest_city', 'life_expectancy', 'maternal_mortality_ratio',
#        'minimum_wage', 'official_language', 'out_of_pocket_health_expenditure',
#        'physicians_per_thousand', 'population',
#        'population_labor_force_participation', 'tax_revenue', 'total_tax_rate',
#        'unemployment_rate', 'urban_population', 'latitude', 'longitude',
#        'continent'],
#       dtype='object')

# %%
#Ejercicio 1
sns.histplot(x = "birth_rate", data = df, color = "palegreen");

plt.xlabel(" Nacimientos ")
plt.ylabel("Recuento")
plt.title("Tasa de natalidad", fontsize = 10);

# La tasa de natalidad se refiere al numero de nacimientos vivos durante un año, la mayor tasa esta entre 5/10 niños por años

# %%
#Ejercicio 2
sns.regplot(x = "birth_rate", 
                y = "life_expectancy", 
                data = df,
                line_kws = {"color": "black", "linewidth": 1},
                color = "darkcyan")


plt.xlabel("Nacimientos")
plt.ylabel("Esperanza de vida ")
plt.title("Relacion nacimientos/esperanza", fontsize = 10);

# A mayor esperanza de vida menos numero de nacimientos.

# %%
# 3. ¿Cuál es el continente con la mayor cantidad de países en el conjunto de datos? Proporciona el porcentaje de países en ese continente.

df_paises = df.groupby("continent")["country"].count().reset_index()
df_paises
# Out:
#          continent  country
# 0           Africa       53
# 1             Asia       45
# 2  Central America       20
# 3           Europe       47
# 4    North America        2
# 5          Oceania       14
# 6    South America       13

# %%
colores = ["c", "cadetblue", "mediumseagreen", "seagreen", "teal", "turquoise", "lightseagreen"]
plt.pie("country", labels= "continent",
        data = df_paises, 
        autopct=  '%1.1f%%', 
        colors = colores, 
        textprops={'fontsize': 8}, 
        startangle=90);

plt.xlabel("Continentes")
plt.title("Relacion paises", fontsize = 10);

# El continente con mayor numero de paises es Africa

# %%
# 4. ¿Cuál es la mediana de la esperanza de vida en Europa? Proporciona un rango intercuartil aproximado y verifica si existen valores atípicos. 

df_paises2 = df.loc[df["continent"] == "Europe"]
df_paises2.head()
# Out:
#     country  density abbreviation  agricultural_land  land_area  \
# 1   Albania    105.0           AL               43.1     28.748
# 3   Andorra    164.0           AD               40.0    468.000
# 9   Austria    109.0           AT               32.4     83.871
# 15  Belarus     47.0           BY               42.0    207.600
# 16  Belgium    383.0           BE               44.6     30.528
#
#     armed_forces_size  birth_rate  calling_code capital/major_city  \
# 1                 9.0       11.78         355.0             Tirana
# 3                 NaN        7.20         376.0   Andorra la Vella
# 9                21.0        9.70          43.0             Vienna
# 15              155.0        9.90         375.0              Minsk
# 16               32.0       10.30          32.0   City of Brussels
#
#     co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 1           4.536  119.05         1.4           ALL            1.62
# ...

# %%
sns.boxplot(y = "life_expectancy", 
            data = df_paises2, 
            width = 0.5, 
            color = "plum")


plt.ylabel("Esperanza de vida ")
plt.title("Esperanza de vida en Europa", fontsize = 10);

# La esperanza de vida esta entorno a los 80 años

# %%
#5. ¿Existen relaciones visibles entre la tasa de natalidad y las siguientes variables: tasa de mortalidad infantil, esperanza de vida, densidad de población y población urbana? Usa un subplot. Describe cualquier patrón que encuentres.

fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (20, 10))
#axes=axes.flat # Aplana los ejes y podemos acceder y no tenemos que entrar por posicion


sns.regplot(x = "birth_rate", y = "infant_mortality", data = df, 
            marker = "d", 
            line_kws = {"color": "black", "linewidth": 1},
            scatter_kws = {"color": "teal", "s": 1}, 
            ax = axes[0][0]
            )

axes[0][0].set_title("elación entre la natalidad y la mortalidad infantil")
# cambiamos el nombre del eje x e y usando el método '.set_xlabel()' y '.set_ylabel()' respectivamente. 
axes[0][0].set_xlabel("natalidad")
# cambiamos el nombre de los ejes usando los métodos
axes[0][0].set_ylabel("Esperanza de vida")
# quitamos la linea de la derecha de la gráfica
axes[0][0].spines['right'].set_visible(False)
# quitamos la linea de la derecha de la gráfica
axes[0][0].spines['top'].set_visible(False);

sns.regplot(x = "birth_rate", y = "life_expectancy", data = df, 
            marker = "d", 
            line_kws = {"color": "black", "linewidth": 1},
            scatter_kws = {"color": "teal", "s": 1}, 
            ax = axes[0][1]
            )


axes[0][1].set_title("Relación entre la natalidad y la densidad de poblacion")
# cambiamos el nombre del eje x e y usando el método '.set_xlabel()' y '.set_ylabel()' respectivamente. 
axes[0][1].set_xlabel("natalidad")
# cambiamos el nombre de los ejes usando los métodos
axes[0][1].set_ylabel("densidad de poblacion")
# quitamos la linea de la derecha de la gráfica
axes[0][1].spines['right'].set_visible(False)
# quitamos la linea de la derecha de la gráfica
axes[0][1].spines['top'].set_visible(False);

sns.regplot(x = "birth_rate", y = "density", data = df, 
            marker = "d", 
            line_kws = {"color": "black", "linewidth": 1},
            scatter_kws = {"color": "teal", "s": 1}, 
            ax = axes[1][0]
            )

axes[1][0].set_title("Relación entre la natalidad y la esperanza de vida")
# cambiamos el nombre del eje x e y usando el método '.set_xlabel()' y '.set_ylabel()' respectivamente. 
axes[1][0].set_xlabel("natalidad")
# cambiamos el nombre de los ejes usando los métodos
axes[1][0].set_ylabel("Mortalidad")
# quitamos la linea de la derecha de la gráfica
axes[1][0].spines['right'].set_visible(False)
# quitamos la linea de la derecha de la gráfica
axes[1][0].spines['top'].set_visible(False);



sns.regplot(x = "birth_rate", y = "urban_population", data = df, 
            marker = "d", 
            line_kws = {"color": "black", "linewidth": 1},
            scatter_kws = {"color": "teal", "s": 1}, 
            ax = axes[1][1]
            )

axes[1][1].set_title("Relación entre la natalidad y la poblacion urbana")
# cambiamos el nombre del eje x e y usando el método '.set_xlabel()' y '.set_ylabel()' respectivamente. 
axes[1][1].set_xlabel("natalidad")
# cambiamos el nombre de los ejes usando los métodos
axes[1][1].set_ylabel("poblacion urbana")
# quitamos la linea de la derecha de la gráfica
axes[1][1].spines['right'].set_visible(False)
# quitamos la linea de la derecha de la gráfica
axes[1][1].spines['top'].set_visible(False);


# las graficas de motartalidad y natalidad son proporcionales 
# Esperanza de vida y natalidad son inversamente proporcionales (a mayor esperanza de vida menor tasa de natalidad)
# La densidad se mantiene estable con la natalidad igual que con la grafica de poblacion urbana

# %%
# Ejercicio 6 ¿Cuáles son los 10 países con la mayor área forestal?

df_paises_3 = df.groupby("country")["forested_area"].sum().reset_index().sort_values(by="forested_area", ascending=False)
top_ten_forest= df_paises_3[:10]

sns.countplot(x = "country", 
              data = top_ten_forest, 
              palette = "viridis", 
              hue = "forested_area")


plt.xlabel("Area forestal")
plt.ylabel("Recuento")
plt.xticks(rotation = 45)
plt.title("Top 10 paises AREA FORESTAL", fontsize = 10);

# %%
colores = ['aqua', 'steelblue', 'c', 'turquoise', 'mintcream', 
           'skyblue', 'seagreen', 'g', 'lavender', 'b']

plt.pie("forested_area", labels= "country",
        data = top_ten_forest, 
        autopct=  '%1.1f%%', 
        colors = colores, 
        textprops={'fontsize': 8}, 
        startangle=90);

# %%
# Ejercicio 7. ¿Existen diferencias notables en la distribución de la tasa de natalidad entre continentes?

# %%
df_continente_3 = df.groupby("continent")["birth_rate"].sum().reset_index()
df_continente_3
# Out:
#          continent  birth_rate
# 0           Africa     1659.12
# 1             Asia      827.69
# 2  Central America      333.78
# 3           Europe      447.98
# 4    North America       21.70
# 5          Oceania      277.39
# 6    South America      221.43

# %%
colores = ["c", "cadetblue", "mediumseagreen", "seagreen", "teal", "turquoise", "lightseagreen", "pink", "orange", "black"]

plt.pie("birth_rate", labels= "continent",
        data = df_continente_3, 
        autopct=  '%1.1f%%', 
        colors = colores, 
        textprops={'fontsize': 8}, 
        startangle=90);


plt.title("Natalidad por continentes", fontsize = 10);

# %%
df.columns
# Out:
# Index(['country', 'density', 'abbreviation', 'agricultural_land', 'land_area',
#        'armed_forces_size', 'birth_rate', 'calling_code', 'capital/major_city',
#        'co2-emissions', 'cpi', 'cpi_change', 'currency-code', 'fertility_rate',
#        'forested_area', 'gasoline_price', 'gdp',
#        'gross_primary_education_enrollment',
#        'gross_tertiary_education_enrollment', 'infant_mortality',
#        'largest_city', 'life_expectancy', 'maternal_mortality_ratio',
#        'minimum_wage', 'official_language', 'out_of_pocket_health_expenditure',
#        'physicians_per_thousand', 'population',
#        'population_labor_force_participation', 'tax_revenue', 'total_tax_rate',
#        'unemployment_rate', 'urban_population', 'latitude', 'longitude',
#        'continent'],
#       dtype='object')

# %%
# Ejercicio 8 ¿Cómo se relacionan el CPI y el precio de la gasolina? Crea un scatter plot que muestre esta relación y agrega una línea para visualizar la tendencia. Ajusta los valores del CPI entre 100 y 300.

sns.regplot(x = "cpi", y = "gasoline_price", data = df, 
            marker = "d", 
            line_kws = {"color": "black", "linewidth": 1}, # cambiamos el color y el grosor de la linea de tendencia
            scatter_kws = {"color": "orchid", "s": 2}, # cambiamos el color y el tamaño de los puntos del scaterplot
            
            )

plt.xlim(100, 300)

plt.xlabel("IPC")
plt.ylabel("Precio gasolina")
# plt.xticks(rotation = 90)
plt.title("Relacion IPC / Precio gasolina", fontsize = 10);


# Cuando subia IPC bajaba el precio de la gasolina

# %%
# Ejercicio 9 ¿Cómo varía la esperanza de vida entre los diferentes países de Oceanía? Utiliza un diagrama de violín para representar la distribución de la esperanza de vida en función del idioma oficial de cada país.


df_paises3 = df.loc[df["continent"] == "Oceania"]
df_paises3.head()
# Out:
#                             country  density abbreviation  agricultural_land  \
# 8                         Australia      3.0           AU               48.2
# 58                             Fiji     49.0           FJ               23.3
# 89                         Kiribati    147.0           KI               42.0
# 107                Marshall Islands    329.0           MH               63.9
# 111  Federated States of Micronesia    784.0           FM               31.4
#
#      land_area  armed_forces_size  birth_rate  calling_code  \
# 8          NaN               58.0       12.60          61.0
# 58      18.274                4.0       21.28         679.0
# 89     811.000                NaN       27.89         686.0
# 107    181.000                NaN       29.03         692.0
# 111    702.000                NaN       22.82         691.0
#
#     capital/major_city  co2-emissions     cpi  cpi_change currency-code  \
# ...

# %%
df_paises3.head(2)
# Out:
#       country  density abbreviation  agricultural_land  land_area  \
# 8   Australia      3.0           AU               48.2        NaN
# 58       Fiji     49.0           FJ               23.3     18.274
#
#     armed_forces_size  birth_rate  calling_code capital/major_city  \
# 8                58.0       12.60          61.0           Canberra
# 58                4.0       21.28         679.0               Suva
#
#     co2-emissions    cpi  cpi_change currency-code  fertility_rate  \
# 8         375.908  119.8         1.6           AUD            1.74
# 58          2.046  132.3         1.8           FJD            2.77
#
#     forested_area  gasoline_price           gdp  \
# 8            16.3            0.93  1.392681e+12
# 58           55.9            0.82  5.535549e+09
#
#     gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 8                                100.3                                113.1
# ...

# %%
# sns.violinplot(y = "life_expectancy", 
#                data = df_paises3, 
#                width = 0.5, 
#                color = "turquoise", 
#                linewidth = 2, hue="country" )


sns.violinplot(x = "life_expectancy", 
               y = "country", 
               data = df_paises3,
               palette = "magma")

plt.xlabel("Esperanza de vida")
plt.ylabel("Ciudad")
# plt.xticks(rotation = 90)
plt.title("Esperanza de vida en oceania", fontsize = 10);

# %%
# ejercicio 10
# Queremos analizar la relación entre la tasa de impuestos total, el PIB per cápita y la tasa de alfabetización. Crea un conjunto de subplots con tres gráficas:

# Un scatter plot que muestre la relación entre el PIB per cápita y el CPI.

# Un histograma de la tasa de impuestos total.

# Un gráfico de barras que resuma la tasa de impuestos total por continente.

# %%
df_continente_4 = df.groupby("continent")["total_tax_rate"].sum().reset_index()
df_continente_4
# Out:
#          continent  total_tax_rate
# 0           Africa          2436.3
# 1             Asia          1367.0
# 2  Central America           793.8
# 3           Europe          1620.5
# 4    North America            61.1
# 5          Oceania           474.2
# 6    South America           680.6

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (20,5))
axes=axes.flat

sns.scatterplot(x = "cpi", 
                y = "gross_primary_education_enrollment", 
                data = df, 
                size = 5, 
                marker= "v",
                ax = axes[0])

axes[0].set_title("Relación entre la suma de impuestos  y PIB")
# cambiamos el nombre del eje x e y usando el método '.set_xlabel()' y '.set_ylabel()' respectivamente. 
axes[0].set_xlabel("PIB")
# cambiamos el nombre de los ejes usando los métodos
axes[0].set_ylabel("Impuestos")


sns.histplot(x = "total_tax_rate", 
             data = df, 
             color = "violet", 
             kde = True, 
             bins = 10 ,
             ax = axes[1])

axes[1].set_title("Impuestos")
# cambiamos el nombre del eje x e y usando el método '.set_xlabel()' y '.set_ylabel()' respectivamente. 
axes[1].set_xlabel("Tasa impuestos")

             
# plt.hist(x = "total_tax_rate", 
#          data = df_continente_4, 
#          bins = 20, 
#          color = "violet", 
#          edgecolor = "black", 
#          density = True, 
#          ax = axes[2])

sns.countplot(x = "continent",
         data = df_continente_4,
         color = "g", 
         hue="continent",
         ax = axes[2]
         )

plt.xticks(rotation = 45)

axes[1].set_title("Suma")
# cambiamos el nombre del eje x e y usando el método '.set_xlabel()' y '.set_ylabel()' respectivamente. 
axes[1].set_xlabel("Tasa impuestos por continentes")
# Out:
# Text(0.5, 0, 'Tasa impuestos por continentes')
