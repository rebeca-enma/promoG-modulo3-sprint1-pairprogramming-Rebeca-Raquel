# %%
from src import soporte_pair_ETL as sp

import pandas as pd

# %%
df_clientes = sp.apertura_csv('files/ventas.csv')

# %%
df_clientes
# Out:
#            ID_Producto Fecha_Venta  Cantidad  Total
# ID_Cliente
# 723                 A1  2023-11-22         2  17.98
# 498                 C3  2023-11-21         1   5.49
# 121                 D4  2023-11-20         3  32.97
# 885                L12  2023-11-19         1   6.49
# 347                Q17  2023-11-18         2   7.98
# ...                ...         ...       ...    ...
# 234              AR136  2023-09-04         1   8.45
# 987              AS137  2023-09-03         2  12.50
# 543              AT138  2023-09-02         1   4.75
# 234              AU139  2023-09-01         2   9.98
# 987              AV140  2023-08-31         1   5.25
#
# [100 rows x 4 columns]

# %%
df_clientes
# Out:
#             ID de Cliente ID_Producto Fecha_Venta  Cantidad  Total
# ID_Cliente
# 723                   723          A1  2023-11-22         2  17.98
# 498                   498          C3  2023-11-21         1   5.49
# 121                   121          D4  2023-11-20         3  32.97
# 885                   885         L12  2023-11-19         1   6.49
# 347                   347         Q17  2023-11-18         2   7.98
# ...                   ...         ...         ...       ...    ...
# 234                   234       AR136  2023-09-04         1   8.45
# 987                   987       AS137  2023-09-03         2  12.50
# 543                   543       AT138  2023-09-02         1   4.75
# 234                   234       AU139  2023-09-01         2   9.98
# 987                   987       AV140  2023-08-31         1   5.25
#
# [100 rows x 5 columns]

# %%
hola
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 hola
#
# NameError: name 'hola' is not defined

# %%
pd.read_csv("files/productos.csv", on_bad_lines='warn', index_col=False)
# Out:
# Skipping line 9: expected 7 fields, saw 9
# Skipping line 10: expected 7 fields, saw 8
# Skipping line 14: expected 7 fields, saw 8
# Skipping line 17: expected 7 fields, saw 8
# Skipping line 23: expected 7 fields, saw 8
# Skipping line 27: expected 7 fields, saw 9
# Skipping line 28: expected 7 fields, saw 10
# Skipping line 29: expected 7 fields, saw 8
# Skipping line 30: expected 7 fields, saw 9
# Skipping line 31: expected 7 fields, saw 9
# Skipping line 32: expected 7 fields, saw 9
# Skipping line 33: expected 7 fields, saw 9
#       ID                 Nombre_Producto             Categoría  Precio  \
# 0     A1                Pizza Margherita     Platos Preparados    8.99
# 1     B2          Risotto de Champiñones     Platos Preparados    6.75
# 2     C3                        Tiramisú               Postres    5.49
# 3     D4                       Panettone            Repostería   10.99
# 4     E5                     Orecchiette       Productos Secos    4.29
# ...
